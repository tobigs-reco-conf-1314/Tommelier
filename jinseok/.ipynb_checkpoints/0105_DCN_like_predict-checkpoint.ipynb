# %%
cd /content/drive/MyDrive/논문/DCN
# Out:
# /content/drive/MyDrive/논문/DCN

# %%
ls
# Out:
# 0105_DCN_like_predict.ipynb  user_test_v2.json
# 1220_dcn.ipynb               user_train_v2.json
# test_v2_201130.json          Wine_segment_201229.csv
# train_v2_201130.json         Wine_segment_scaled_201231.csv

# %%
# !pip install -q tensorflow-recommenders
# !pip install -q --upgrade tensorflow-datasets
# Out:
#      |████████████████████████████████| 51kB 5.0MB/s
#      |████████████████████████████████| 3.6MB 8.2MB/s

# %%
import os
import sys
import gc
import glob
import joblib
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

import tensorflow as tf
import tensorflow_recommenders as tfrs

from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, Callback
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 0. Data Load

# %%
# 0. Data Load

# %%
train = pd.read_json('train_v2_201130.json')
test = pd.read_json('test_v2_201130.json')

# %%
train.head()
# Out:
#    index  ... like
# 0      0  ...    1
# 1      1  ...    1
# 2      4  ...    1
# 3      5  ...    1
# 4      6  ...    0
#
# [5 rows x 10 columns]

# %%
train.shape, test.shape
# Out:
# ((763387, 10), (188718, 10))

# %%
item = pd.read_csv('Wine_segment_201229.csv')

# %%
item.head()
# Out:
#    wine_id                        name  ...  winery_id  segment
# 0  1938520     1882 Cabernet Sauvignon  ...     2412.0        2
# 1    14604      Les Bessards Hermitage  ...     7636.0        2
# 2  1930757      Patriarch Estate Grown  ...     1905.0        2
# 3  1564280                      Merlot  ...     1297.0        2
# 4  2576427  Cabernet Sauvignon F Block  ...     2232.0        2
#
# [5 rows x 152 columns]

# %% [markdown]
# # 1. Data Preprocess

# %%
train = train[['userID', 'wine_id', 'rating_per_user', 'like']]
test = test[['userID', 'wine_id', 'rating_per_user', 'like']]

# %%
selected_item = item[[
      'wine_id',
      'rating_count',
      'rating_average',
      'review_count',
      'label_count',
      'body',
      'acidity_y',
      'alcohol',
      'type_id',
      'grapes_id',
      'country_code',
      'region_id',
      'segment'
]]

selected_item
# Out:
#        wine_id  rating_count  rating_average  ...  country_code  region_id  segment
# 0      1938520          1697             4.1  ...            us      105.0        2
# 1        14604          1078             4.3  ...            fr      535.0        2
# 2      1930757          1072             4.6  ...            us       88.0        2
# 3      1564280          3577             4.3  ...            us       24.0        2
# 4      2576427           115             4.4  ...            us       42.0        2
# ...        ...           ...             ...  ...           ...        ...      ...
# 50855  1669561           788             3.5  ...            it      983.0        1
# 50856  1861275           231             3.8  ...            it      613.0        1
# 50857  2201892           390             3.9  ...            it     3232.0        1
# 50858  2396179           302             4.2  ...            fr      635.0        3
# 50859  7715684            82             4.1  ...            es     1687.0        2
#
# [50860 rows x 13 columns]

# %%
train.loc[train['wine_id'] == 1886805, 'wine_id'] = 1183966
test.loc[test['wine_id'] == 1886805, 'wine_id'] = 1183966

# %%
add_train = train.merge(selected_item, on = 'wine_id', how = 'left')
add_test = test.merge(selected_item, on = 'wine_id', how = 'left')

add_train
# Out:
#           userID  wine_id  rating_per_user  ...  country_code  region_id  segment
# 0       19484511  1141133              4.0  ...            fr      409.0        3
# 1         352674  1141133              4.0  ...            fr      409.0        3
# 2       17786617  1141133              4.0  ...            fr      409.0        3
# 3        8078038  1141133              4.5  ...            fr      409.0        3
# 4        3014532  1141133              4.0  ...            fr      409.0        3
# ...          ...      ...              ...  ...           ...        ...      ...
# 763382  11274168    87064              3.0  ...            es      766.0        1
# 763383  11274168    63654              4.0  ...            fr      387.0        3
# 763384  11274168     5602              4.5  ...            us       96.0        3
# 763385  11274168  1396664              3.0  ...            us       25.0        2
# 763386  11274168  1142712              3.5  ...            us      327.0        2
#
# [763387 rows x 16 columns]

# %%
add_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763387 entries, 0 to 763386
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   userID           763387 non-null  int64
#  1   wine_id          763387 non-null  int64
#  2   rating_per_user  763387 non-null  float64
#  3   like             763387 non-null  int64
#  4   rating_count     763387 non-null  int64
#  5   rating_average   763387 non-null  float64
#  6   review_count     763387 non-null  int64
#  7   label_count      763387 non-null  int64
#  8   body             763387 non-null  float64
#  9   acidity_y        763387 non-null  float64
#  10  alcohol          763387 non-null  float64
#  11  type_id          763387 non-null  int64
#  12  grapes_id        763387 non-null  object
#  13  country_code     763387 non-null  object
#  14  region_id        763387 non-null  float64
#  15  segment          763387 non-null  int64
# dtypes: float64(6), int64(8), object(2)
# memory usage: 99.0+ MB

# %%
add_train.isnull().sum()
# Out:
# userID             0
# wine_id            0
# rating_per_user    0
# like               0
# rating_count       0
# rating_average     0
# review_count       0
# label_count        0
# body               0
# acidity_y          0
# alcohol            0
# type_id            0
# grapes_id          0
# country_code       0
# region_id          0
# segment            0
# dtype: int64

# %%
add_train.head()
# Out:
#      userID  wine_id  rating_per_user  ...  country_code  region_id  segment
# 0  19484511  1141133              4.0  ...            fr      409.0        3
# 1    352674  1141133              4.0  ...            fr      409.0        3
# 2  17786617  1141133              4.0  ...            fr      409.0        3
# 3   8078038  1141133              4.5  ...            fr      409.0        3
# 4   3014532  1141133              4.0  ...            fr      409.0        3
#
# [5 rows x 16 columns]

# %% [markdown]
# # 2. Data Setting

# %%
add_train.columns, len(add_train.columns)
# Out:
# (Index(['userID', 'wine_id', 'rating_per_user', 'like', 'rating_count',
#         'rating_average', 'review_count', 'label_count', 'body', 'acidity_y',
#         'alcohol', 'type_id', 'grapes_id', 'country_code', 'region_id',
#         'segment'],
#        dtype='object'), 16)

# %%
str_features = ['userID', 'wine_id', 'type_id', 'grapes_id', 'country_code', 'region_id', 'segment']
int_features = ['rating_count', 'rating_average', 'review_count', 'label_count', 'body', 'acidity_y', 'alcohol']
label_feature = ['like']
feature_names = str_features + int_features + label_feature
feature_names
# Out:
# ['userID',
#  'wine_id',
#  'type_id',
#  'grapes_id',
#  'country_code',
#  'region_id',
#  'segment',
#  'rating_count',
#  'rating_average',
#  'review_count',
#  'label_count',
#  'body',
#  'acidity_y',
#  'alcohol',
#  'like']

# %%
import DCN
import imp
imp.reload(DCN)
# Out:
# <module 'DCN' from '/content/drive/MyDrive/논문/DCN/DCN.py'>

# %%
cached_train, vocabularies = DCN.preprocessing(add_train, str_features, int_features, df_type = 'train')

# %%
cached_test = DCN.preprocessing(add_test, str_features, int_features, df_type = 'test')

# %%
cached_train
# Out:
# <CacheDataset shapes: {userID: (None,), wine_id: (None,), type_id: (None,), grapes_id: (None,), country_code: (None,), region_id: (None,), segment: (None,), like: (None,), rating_per_user: (None,), rating_count: (None,), rating_average: (None,), review_count: (None,), label_count: (None,), body: (None,), acidity_y: (None,), alcohol: (None,)}, types: {userID: tf.string, wine_id: tf.string, type_id: tf.string, grapes_id: tf.string, country_code: tf.string, region_id: tf.string, segment: tf.string, like: tf.int64, rating_per_user: tf.float64, rating_count: tf.int64, rating_average: tf.int64, review_count: tf.int64, label_count: tf.int64, body: tf.int64, acidity_y: tf.int64, alcohol: tf.int64}>

# %%
vocabularies

# %% [markdown]
# # 3. Model

# %%
import tensorflow as tf
import keras
class MaskedEmbeddingsAggregatorLayer(tf.keras.layers.Layer):
    def __init__(self, agg_mode='sum', **kwargs):
        super(MaskedEmbeddingsAggregatorLayer, self).__init__(**kwargs)

        if agg_mode not in ['sum', 'mean']:
            raise NotImplementedError('mode {} not implemented!'.format(agg_mode))
        self.agg_mode = agg_mode
    
    @tf.function
    def call(self, inputs, mask=None):
        masked_embeddings = tf.ragged.boolean_mask(inputs, mask)
        if self.agg_mode == 'sum':
            aggregated =  tf.reduce_sum(masked_embeddings, axis=1)
        elif self.agg_mode == 'mean':
            aggregated = tf.reduce_mean(masked_embeddings, axis=1)
        
        return aggregated
    
    def get_config(self):
        # this is used when loading a saved model that uses a custom layer
        return {'agg_mode': self.agg_mode}


class L2NormLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(L2NormLayer, self).__init__(**kwargs)
    
    @tf.function
    def call(self, inputs, mask=None):
        if mask is not None:
            inputs = tf.ragged.boolean_mask(inputs, mask).to_tensor()
        return tf.math.l2_normalize(inputs, axis=-1)

    def compute_mask(self, inputs, mask):
        return mask

# %%
learning_rate = 0.001
model = DCN.model(use_cross_layer = True,
            deep_layer_sizes = [512, 256, 128, 64],
            learning_rate = learning_rate,
            str_features = str_features,
            int_features = int_features,
            vocabularies = vocabularies,
            projection_dim = None,
            metric = 'binary'
            )

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate))

# %% [markdown]
# # 4. Train

# %%
import keras
callbacks_list = [
                  keras.callbacks.EarlyStopping(
                    monitor = 'binary_accuracy',
                    patience = 50
                  )
]

# %%
history = model.fit(cached_train,
                     epochs = 1000,
                     callbacks = callbacks_list,
                     verbose = True)
# Out:
# Epoch 1/1000
# 94/94 [==============================] - 10s 92ms/step - binary_accuracy: 0.6722 - loss: 0.5997 - regularization_loss: 0.0000e+00 - total_loss: 0.5997
# Epoch 2/1000
# 94/94 [==============================] - 8s 87ms/step - binary_accuracy: 0.7371 - loss: 0.5253 - regularization_loss: 0.0000e+00 - total_loss: 0.5253
# Epoch 3/1000
# 94/94 [==============================] - 9s 92ms/step - binary_accuracy: 0
1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9805 - loss: 0.0299 - regularization_loss: 0.0000e+00 - total_loss: 0.0299
# Epoch 164/1000
# 94/94 [==============================] - 9s 90ms/step - binary_accuracy: 0.9805 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 165/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9805 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 166/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9804 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 167/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9804 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 168/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9804 - loss: 0.0302 - regularization_loss: 0.0000e+00 - total_loss: 0.0302
# Epoch 169/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9803 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 170/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9803 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 171/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9803 - loss: 0.0303 - regularization_loss: 0.0000e+00 - total_loss: 0.0303
# Epoch 172/1000
# 94/94 [==============================] - 8s 90ms/step - binary_accuracy: 0.9803 - loss: 0.0305 - regularization_loss: 0.0000e+00 - total_loss: 0.0305
# Epoch 173/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9802 - loss: 0.0305 - regularization_loss: 0.0000e+00 - total_loss: 0.0305
# Epoch 174/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9802 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 175/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9802 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 176/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9802 - loss: 0.0303 - regularization_loss: 0.0000e+00 - total_loss: 0.0303
# Epoch 177/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9801 - loss: 0.0305 - regularization_loss: 0.0000e+00 - total_loss: 0.0305
# Epoch 178/1000
# 94/94 [==============================] - 8s 90ms/step - binary_accuracy: 0.9801 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 179/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9801 - loss: 0.0305 - regularization_loss: 0.0000e+00 - total_loss: 0.0305
# Epoch 180/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9802 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 181/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9801 - loss: 0.0304 - regularization_loss: 0.0000e+00 - total_loss: 0.0304
# Epoch 182/1000
# 94/94 [==============================] - 8s 90ms/step - binary_accuracy: 0.9802 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 183/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9802 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 184/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9802 - loss: 0.0298 - regularization_loss: 0.0000e+00 - total_loss: 0.0298
# Epoch 185/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9802 - loss: 0.0299 - regularization_loss: 0.0000e+00 - total_loss: 0.0299
# Epoch 186/1000
# 94/94 [==============================] - 9s 94ms/step - binary_accuracy: 0.9803 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 187/1000
# 94/94 [==============================] - 9s 90ms/step - binary_accuracy: 0.9803 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 188/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9802 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 189/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9802 - loss: 0.0299 - regularization_loss: 0.0000e+00 - total_loss: 0.0299
# Epoch 190/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9803 - loss: 0.0298 - regularization_loss: 0.0000e+00 - total_loss: 0.0298
# Epoch 191/1000
# 94/94 [==============================] - 8s 87ms/step - binary_accuracy: 0.9803 - loss: 0.0298 - regularization_loss: 0.0000e+00 - total_loss: 0.0298
# Epoch 192/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9803 - loss: 0.0298 - regularization_loss: 0.0000e+00 - total_loss: 0.0298
# Epoch 193/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0298 - regularization_loss: 0.0000e+00 - total_loss: 0.0298
# Epoch 194/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9803 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 195/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9802 - loss: 0.0303 - regularization_loss: 0.0000e+00 - total_loss: 0.0303
# Epoch 196/1000
# 94/94 [==============================] - 9s 90ms/step - binary_accuracy: 0.9803 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 197/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0302 - regularization_loss: 0.0000e+00 - total_loss: 0.0302
# Epoch 198/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 199/1000
# 94/94 [==============================] - 8s 90ms/step - binary_accuracy: 0.9802 - loss: 0.0302 - regularization_loss: 0.0000e+00 - total_loss: 0.0302
# Epoch 200/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9802 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 201/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 202/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 203/1000
# 94/94 [==============================] - 9s 91ms/step - binary_accuracy: 0.9802 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 204/1000
# 94/94 [==============================] - 8s 90ms/step - binary_accuracy: 0.9802 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 205/1000
# 94/94 [==============================] - 8s 88ms/step - binary_accuracy: 0.9803 - loss: 0.0301 - regularization_loss: 0.0000e+00 - total_loss: 0.0301
# Epoch 206/1000
# 94/94 [==============================] - 9s 90ms/step - binary_accuracy: 0.9803 - loss: 0.0300 - regularization_loss: 0.0000e+00 - total_loss: 0.0300
# Epoch 207/1000
# 94/94 [==============================] - 8s 89ms/step - binary_accuracy: 0.9803 - loss: 0.0299 - regularization_loss: 0.0000e+00 - total_loss: 0.0299

# %%
DCN.getResult(model, cached_test, metric = 'binary')
# Out:
# ROC: 0.9562429607918692
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     88227
#            1       0.93      0.92      0.92    100491
#
#     accuracy                           0.92    188718
#    macro avg       0.92      0.92      0.92    188718
# weighted avg       0.92      0.92      0.92    188718

# %%
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_100 (Sequential)  (None, 64)                4224
# _________________________________________________________________
# sequential_101 (Sequential)  (None, 64)                1792
# _________________________________________________________________
# sequential_99 (Sequential)   (None, 64)                576
# _________________________________________________________________
# sequential_92 (Sequential)   (None, 64)                3584
# _________________________________________________________________
# sequential_91 (Sequential)   (None, 64)                37760
# _________________________________________________________________
# sequential_98 (Sequential)   (None, 64)                1370944
# _________________________________________________________________
# sequential_96 (Sequential)   (None, 64)                1728
# _________________________________________________________________
# sequential_95 (Sequential)   (None, 64)                509376
# _________________________________________________________________
# sequential_93 (Sequential)   (None, 64)                122304
# _________________________________________________________________
# sequential_97 (Sequential)   (None, 64)                66304
# _________________________________________________________________
# sequential_94 (Sequential)   (None, 64)                320
# _________________________________________________________________
# sequential_90 (Sequential)   (None, 64)                512
# _________________________________________________________________
# sequential_88 (Sequential)   (None, 64)                406016
# _________________________________________________________________
# sequential_89 (Sequential)   (None, 64)                3254528
# _________________________________________________________________
# cross_6 (Cross)              multiple                  803712
# _________________________________________________________________
# dense_24 (Dense)             multiple                  459264
# _________________________________________________________________
# dense_25 (Dense)             multiple                  131328
# _________________________________________________________________
# dense_26 (Dense)             multiple                  32896
# _________________________________________________________________
# dense_27 (Dense)             multiple                  8256
# _________________________________________________________________
# dense_28 (Dense)             multiple                  65
# _________________________________________________________________
# ranking_6 (Ranking)          multiple                  2
# =================================================================
# Total params: 7,215,491
# Trainable params: 7,215,489
# Non-trainable params: 2
# _________________________________________________________________

# %%
pred = DCN.recommendation(, model, selected_item, str_features, int_features)

# %%
pred.merge(item[['wine_id', 'name']], on = 'wine_id', )
# Out:
#       wine_id          prob                                               name
# 0       15290  1.000000e+00                                             Alttus
# 1       23302  1.000000e+00                                    Sauvignon Blanc
# 2       16972  1.000000e+00                       Rina Ianca Grillo - Viognier
# 3        3580  1.000000e+00                                         Pinot Noir
# 4        8238  1.000000e+00  Barrica Selection Gran Reserva Cabernet Sauvignon
# ...       ...           ...                                                ...
# 4321    18735  3.895329e-10                           Chianti Classico Riserva
# 4322    21585  7.157910e-11                                 Rioja Gran Reserva
# 4323    19323  4.752488e-11                                         Bout d'Zan
# 4324    43664  2.449023e-11           Chablis Premier Cru 'Montée de Tonnerre'
# 4325    22690  5.739572e-12      Vino Nobile di Montepulciano Etichetta Bianca
#
# [4326 rows x 3 columns]

# %%
import seaborn as sns
plt.style.use('seaborn') # seaborn 스타일로 변환
sns.set(rc={'figure.figsize' : (15,15)})

# %%
features, len(features)
# Out:
# (ListWrapper(['userID', 'wine_id', 'type_id', 'grapes_id', 'country_code', 'region_id', 'segment', 'rating_count', 'rating_average', 'review_count', 'label_count', 'body', 'acidity_y', 'alcohol']),
#  14)

# %%
mat = model._cross_layer._dense.kernel
features = model._all_features
block_norm = np.ones([len(features), len(features)])

dim = model.embedding_dimension

# Compute the norms of the blocks.
for i in range(len(features)):
  for j in range(len(features)):
    block = mat[i * dim:(i + 1) * dim,
                j * dim:(j + 1) * dim]
    block_norm[i,j] = np.linalg.norm(block, ord="fro")

plt.figure(figsize=(25,25))
im = plt.matshow(block_norm, cmap=plt.cm.Blues)
ax = plt.gca()
divider = make_axes_locatable(plt.gca())
cax = divider.append_axes("right", size="1%", pad=0.001)
plt.colorbar(im, cax=cax)
cax.tick_params(labelsize=10)
# ax.set_xticklabels(np.arange(1, 15), features, ha="left")
ax.set_xticks(np.arange(0,14))
ax.set_yticks(np.arange(0,14))
_ = ax.set_xticklabels(features, rotation=45, ha="left", fontsize=10)
_ = ax.set_yticklabels(features, fontsize=10)
